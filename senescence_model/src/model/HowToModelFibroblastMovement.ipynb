# %%
# %matplotlib notebook
import ipympl
import matplotlib.pyplot as plt

plt.plot([0, 1, 2, 2])
plt.show()
# Out:
# c:\programdata\miniconda3\lib\site-packages\ipympl\__init__.py:19: UserWarning:
# This call to matplotlib.use() has no effect because the backend has already
# been chosen; matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
# The backend was *originally* set to 'nbAgg' by the following code:
#   File "c:\programdata\miniconda3\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "c:\programdata\miniconda3\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "c:\programdata\miniconda3\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "c:\programdata\miniconda3\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "c:\programdata\miniconda3\lib\site-packages\ipykernel\kernelapp.py", line 497, in start
#     self.io_loop.start()
# ...

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import numpy as np

step = 0.1
unitx = np.array([step, 0, 0])
unity = np.array([0, step, 0])
unitz = np.array([0, 0, step])

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')
a = np.array([1, 3, 5])
b = np.array([4, 2, 9])
print(*zip(a, b))
ax.plot(*zip(a, b, a+0.3*(b-a)), 'ro')
ax.legend()
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.set_zlim(0, 10)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

n = ['a', 'b']
ax.text(*a, "a")
ax.text(*b, "b")
#ax.text(*a+(b-a)*0.4, "a+((b-a)*0.4)")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.
# (1, 4) (3, 2) (5, 9)

# %%
print('a is: {}'.format(a))

print('b is: {}'.format(b))

print('a - b is: {}'.format(a-b))
print('b - a is: {}'.format(b-a))
print('a+((b-a)*0.4) is: {}'.format(a+((b-a)*0.4)))


a+b-a
# Out:
# a is: [1 3 5]
# b is: [4 2 9]
# a - b is: [-3  1 -4]
# b - a is: [ 3 -1  4]
# a+((b-a)*0.4) is: [2.2 2.6 6.6]
# array([4, 2, 9])

# %%
import matplotlib as mpl
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import numpy

mpl.rcParams['legend.fontsize'] = 10

fig = plt.figure()
ax = fig.gca(projection='3d')

scale = 1
bottom_left_back = numpy.array([0, 0, 0])
bottom_left_front = numpy.array([0, 1, 0])
bottom_right_back = numpy.array([1, 0, 0])
bottom_right_front = numpy.array([1, 1, 0])
front_left_back = numpy.array([0, 0, 1])
front_left_front = numpy.array([0, 1, 1])
front_right_back = numpy.array([1, 0, 1])
front_right_front= numpy.array([1, 1, 1])

plot_data = zip(
    bottom_left_back,
    bottom_left_front, 
    bottom_right_back,
    bottom_right_front,
    front_left_back,
    front_left_front,
    front_right_back,
    front_right_front,

)
# print([i for i in plot_data])
x, y, z = [i for i in plot_data]
ax.plot(x, y, z, 'ro')
ax.legend()
ax.set_xlim(0, 10)
ax.set_ylim(0, 10)
ax.set_zlim(0, 10)

ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')

# n = ['a', 'b']
# ax.text(*a, "a")
# ax.text(*b, "b")
# #ax.text(*a+(b-a)*0.4, "a+((b-a)*0.4)")

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# No handles with labels found to put in legend.

# %%
bottom_left_back = (0, 0, 0)

bottom_left_front = (0, self.scale, 0)
bottom_right_back = (self.scale, 0, 0)
bottom_right_front = (0, 0, 0)
front_left_back = (0, 0, 0)
front_left_front = (0, 0, 0)
front_right_back = (0, 0, 0)
front_right_front = (0, 0, 0)

# %%
import numpy

numpy.linspace(0, 1, 10)
# Out:
# array([0.        , 0.11111111, 0.22222222, 0.33333333, 0.44444444,
#        0.55555556, 0.66666667, 0.77777778, 0.88888889, 1.        ])
